# %%
import pandas as pd

# %%
data = pd.read_csv("AppleWatchHeartRate.csv")

# %%
heart_rate_data = data[data['type'] == 'HKQuantityTypeIdentifierHeartRate']

# %%
heart_rate_data = heart_rate_data.drop( ['Unnamed: 0', 'type', 'unit', 'startDate'] , axis = 1)

# %%
heart_rate_data
# Out:
#                    creationDate                    endDate    value
# 0     2020-06-13 02:50:42 +0900  2020-06-13 02:50:23 +0900  79.5536
# 1     2020-06-13 02:55:24 +0900  2020-06-13 02:55:10 +0900       81
# 2     2020-06-13 03:01:15 +0900  2020-06-13 02:57:08 +0900       85
# 3     2020-06-13 03:06:23 +0900  2020-06-13 03:02:43 +0900       89
# 4     2020-06-13 03:12:22 +0900  2020-06-13 03:08:34 +0900       89
# 5     2020-06-13 03:16:02 +0900  2020-06-13 03:14:43 +0900       90
# 6     2020-06-13 03:20:45 +0900  2020-06-13 03:19:02 +0900       88
# 7     2020-06-13 03:27:36 +0900  2020-06-13 03:22:03 +0900       88
# 8     2020-06-13 03:32:06 +0900  2020-06-13 03:28:42 +0900       88
# 9     2020-06-13 03:36:00 +0900  2020-06-13 03:34:11 +0900       86
# 10    2020-06-13 03:39:41 +0900  2020-06-13 03:38:34 +0900  86.2921
# 11    2020-06-13 03:50:10 +0900  2020-06-13 03:38:24 +0900       87
# 12    2020-06-13 03:50:10 +0900  2020-06-13 03:43:12 +0900       89
# ...

# %% [markdown]
# For this particular patient, a warning should be generated if heart rate falls **below 60 counts/min** or increases **above 115 counts/min**

# %%
vals = heart_rate_data['value']

# %%
v = pd.to_numeric(vals)

# %%
for i in range(0,1319):
    if v[i] < 60 or v[i] > 115:
        print ('warning!')
# Out:
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# warning!
# ...

# %%
pip install anvil-uplink
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import anvil.server

anvil.server.connect("ER6FH2QK5RGQ6ODTOF2LU2F3-VXAV2KGJKUAIPPHO")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment (dev)" as SERVER

# %%
@anvil.server.callable

def give_warning():
    for i in range(0,1319):
    if v[i] < 60 or v[i] > 115:
        alert ('warning!')

# %% [markdown]
# Whenever a warning is generated, the at home healthcare provider can check up on the patient and manually disable for the functioning to restart.
